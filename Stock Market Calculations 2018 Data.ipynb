# %%
#Load Library

# %%
install.packages("languagesever")
library(dplyr)

# %%
#Load in csv files and assign to dataframe

# %%
apple_df<- read.csv("aapl-1.csv")
amazon_df<- read.csv("amzn-1.csv")
google_df<- read.csv("goog-1.csv")
ibm_df<- read.csv("ibm-1.csv")
meta_df<- read.csv("meta-1.csv")
msft_df<- read.csv("msft-1.csv")

# %%
#Checking variable names and types

# %%
str(apple_df)
# Out:
# 'data.frame':	250 obs. of  7 variables:
#  $ Date     : chr  "28-Dec-18" "27-Dec-18" "26-Dec-18" "24-Dec-18" ...
#  $ Open     : num  39.4 39 37.1 37 39.2 ...
#  $ High     : num  39.6 39.2 39.3 37.9 39.5 ...
#  $ Low      : num  38.6 37.5 36.7 36.6 37.4 ...
#  $ Close    : num  39.1 39 39.3 36.7 37.7 ...
#  $ Adj.Close: num  37.4 37.3 37.6 35.1 36 ...
#  $ Volume   : chr  "169,165,600" "212,468,400" "234,330,000" "148,676,800" ...

# %%
#Code to calculate APPLE close ratio, adjusted close ratio, difference, and divided

# %%
apple_df2 <- apple_df %>%
  mutate(
    Close_Ratio = lead(Close, n = 1) / Close,
    Adjusted_Close_Ratio = lead(Adj.Close, n = 1) / Adj.Close,
    Difference = Adjusted_Close_Ratio - Close_Ratio,
    Dividend = Difference * Close
    )
apple_df2
# Out:
#     Date      Open  High  Low   Close Adj.Close Volume      Close_Ratio
# 1   28-Dec-18 39.38 39.63 38.64 39.06 37.35     169,165,600 0.9994880
# 2   27-Dec-18 38.96 39.19 37.52 39.04 37.33     212,468,400 1.0064037
# 3   26-Dec-18 37.08 39.31 36.68 39.29 37.57     234,330,000 0.9343344
# 4   24-Dec-18 37.04 37.89 36.65 36.71 35.10     148,676,800 1.0264233
# 5   21-Dec-18 39.22 39.54 37.41 37.68 36.03     382,978,400 1.0406051
# 6   20-Dec-18 40.10 40.53 38.83 39.21 37.49     259,092,000 1.0257587
# 7   19-Dec-18 41.50 41.86 39.77 40.22 38.46     196,189,200 1.0323222
# 8   18-Dec-18 41.35 41.88 41.10 41.52 39.70     135,366,000 0.9872351
# 9   17-Dec-18 41.36 42.09 40.68 40.99 39.19     177,151,600 1.0092706
# 10  14-Dec-18 42.25 42.27 41.32 41.37 39.56     162,814,800 1.0331158
# 11  13-Dec-18 42.62 43.14 42.39 42.74 40.86     127,594,400 0.9892372
# 12  12-Dec-18 42.60 42.98 42.26 42.28 40.42     142,510,800 0.9971618
# ...

# %%
#Code for APPLE table of date and dividend only.

# %%
select(apple_df2, Date, Dividend)
# Out:
#     Date      Dividend
# 1   28-Dec-18 -0.0009156627
# 2   27-Dec-18  0.0009938387
# 3   26-Dec-18 -0.0030795848
# 4   24-Dec-18  0.0026581197
# 5   21-Dec-18 -0.0031390508
# 6   20-Dec-18  0.0045025340
# 7   19-Dec-18 -0.0032553302
# 8   18-Dec-18 -0.0033803526
# 9   17-Dec-18  0.0069941312
# 10  14-Dec-18 -0.0105207280
# 11  13-Dec-18 -0.0002447381
# 12  12-Dec-18  0.0049381494
# 13  11-Dec-18  0.0005556934
# 14  10-Dec-18  0.0080710409
# 15  7-Dec-18  -0.0019364449
# 16  6-Dec-18   0.0014915011
# 17  4-Dec-18  -0.0113589015
# 18  3-Dec-18   0.0015368945
# 19  30-Nov-18  0.0005598501
# 20  29-Nov-18 -0.0048532153
# 21  28-Nov-18  0.0063815029
# 22  27-Nov-18  0.0041272509
# 23  26-Nov-18  0.0048322952
# 24  23-Nov-18 -0.0011629036
# 25  21-Nov-18  0.0022834832
# 26  20-Nov-18 -0.0132947294
# 27  19-Nov-18  0.0040243079
# 28  16-Nov-18  0.0070860355
# 29  15-Nov-18 -0.0106971154
# 30  14-Nov-18 -0.0003135498
# ⋮   ⋮         ⋮
# 221 13-Feb-18 -0.0017086979
# ...

# %%
#Code to calculate AMAZON close ratio, adjusted ratio, difference, and dividend

# %%
amazon_df2 <- amazon_df %>%
  mutate(
    Close_Ratio = lead(Close, n = 1) / Close,
    Adjusted_Close_Ratio = lead(Adj.Close, n = 1) / Adj.Close,
    Difference = Adjusted_Close_Ratio - Close_Ratio,
    Dividend = Difference * Close
    )
amazon_df2
# Out:
#     Date      Open  High  Low   Close Adj.Close Volume      Close_Ratio
# 1   28-Dec-18 73.67 75.67 72.45 73.90 73.90     176,580,000 0.9889039
# 2   27-Dec-18 72.71 73.45 69.52 73.08 73.08     194,440,000 1.0062945
# 3   26-Dec-18 68.44 73.66 68.15 73.54 73.54     208,236,000 0.9137884
# 4   24-Dec-18 67.30 69.80 65.35 67.20 67.20     144,400,000 1.0248512
# 5   21-Dec-18 73.25 74.00 68.20 68.87 68.87     272,806,000 1.0605489
# 6   20-Dec-18 74.20 75.47 71.63 73.04 73.04     199,836,000 1.0234118
# 7   19-Dec-18 77.15 79.23 74.16 74.75 74.75     175,844,000 1.0377258
# 8   18-Dec-18 77.00 78.38 76.15 77.57 77.57     130,460,000 0.9804048
# 9   17-Dec-18 78.30 78.81 75.25 76.05 76.05     176,596,000 1.0466798
# 10  14-Dec-18 81.90 82.13 79.25 79.60 79.60     127,344,000 1.0417085
# 11  13-Dec-18 84.00 84.61 82.07 82.92 82.92     105,426,000 1.0031356
# 12  12-Dec-18 83.45 85.25 83.01 83.18 83.18     131,960,000 0.9877374
# ...

# %%
#Code for AMAZON table of date and dividend only.

# %%
select(amazon_df2, Date, Dividend)
# Out:
#     Date      Dividend
# 1   28-Dec-18 0
# 2   27-Dec-18 0
# 3   26-Dec-18 0
# 4   24-Dec-18 0
# 5   21-Dec-18 0
# 6   20-Dec-18 0
# 7   19-Dec-18 0
# 8   18-Dec-18 0
# 9   17-Dec-18 0
# 10  14-Dec-18 0
# 11  13-Dec-18 0
# 12  12-Dec-18 0
# 13  11-Dec-18 0
# 14  10-Dec-18 0
# 15  7-Dec-18  0
# 16  6-Dec-18  0
# 17  4-Dec-18  0
# 18  3-Dec-18  0
# 19  30-Nov-18 0
# 20  29-Nov-18 0
# 21  28-Nov-18 0
# 22  27-Nov-18 0
# 23  26-Nov-18 0
# 24  23-Nov-18 0
# 25  21-Nov-18 0
# 26  20-Nov-18 0
# 27  19-Nov-18 0
# 28  16-Nov-18 0
# 29  15-Nov-18 0
# 30  14-Nov-18 0
# ⋮   ⋮         ⋮
# 221 13-Feb-18  0
# 222 12-Feb-18  0
# 223 9-Feb-18   0
# 224 8-Feb-18   0
# 225 7-Feb-18   0
# 226 6-Feb-18   0
# 227 5-Feb-18   0
# 228 2-Feb-18   0
# 229 1-Feb-18   0
# 230 31-Jan-18  0
# 231 30-Jan-18  0
# 232 29-Jan-18  0
# 233 26-Jan-18  0
# 234 25-Jan-18  0
# 235 24-Jan-18  0
# 236 23-Jan-18  0
# 237 22-Jan-18  0
# 238 19-Jan-18  0
# 239 18-Jan-18  0
# 240 17-Jan-18  0
# 241 16-Jan-18  0
# ...

# %%
#Code to calculate GOOGLE close ratio, adjusted close ratio, difference between ratios, and dividend

# %%
google_df2 <- google_df %>%
  mutate(
    Close_Ratio = lead(Close, n = 1) / Close,
    Adjusted_Close_Ratio = lead(Adj.Close, n = 1) / Adj.Close,
    Difference = Adjusted_Close_Ratio - Close_Ratio,
    Dividend = Difference * Close
    )
google_df2
# Out:
#     Date      Open  High  Low   Close Adj.Close Volume     Close_Ratio
# 1   28-Dec-18 52.48 52.78 51.65 51.85 51.73     28,296,000 1.0065574
# 2   27-Dec-18 50.86 52.19 49.85 52.19 52.07     42,196,000 0.9957846
# 3   26-Dec-18 49.45 52.00 49.15 51.97 51.85     47,466,000 0.9391957
# 4   24-Dec-18 48.69 50.18 48.51 48.81 48.69     31,806,000 1.0034829
# 5   21-Dec-18 50.76 51.20 48.68 48.98 48.86     91,920,000 1.0304206
# 6   20-Dec-18 50.91 51.71 49.82 50.47 50.35     53,470,000 1.0134734
# 7   19-Dec-18 51.70 53.10 50.40 51.15 51.03     49,586,000 1.0056696
# 8   18-Dec-18 51.30 52.47 51.07 51.44 51.31     43,850,000 0.9881415
# 9   17-Dec-18 51.88 52.66 50.40 50.83 50.70     47,708,000 1.0249852
# 10  14-Dec-18 52.50 53.13 52.04 52.10 51.98     33,732,000 1.0191939
# 11  13-Dec-18 53.40 53.99 52.70 53.10 52.96     26,596,000 1.0015066
# 12  12-Dec-18 53.40 54.08 53.14 53.18 53.05     30,476,000 0.9889056
# 13  11-Dec-18 52.82 53.03 51.99 52.59 52.46     27,894,000 0.9884008
# ...

# %%
#Code for GOOGLE table of date and dividend only.

# %%
select(google_df2, Date, Dividend)
# Out:
#     Date      Dividend
# 1   28-Dec-18  0.0007887106
# 2   27-Dec-18 -0.0005070098
# 3   26-Dec-18 -0.0073134041
# 4   24-Dec-18  0.0004189772
# 5   21-Dec-18  0.0036594351
# 6   20-Dec-18  0.0016206554
# 7   19-Dec-18 -0.0093415638
# 8   18-Dec-18 -0.0015455077
# 9   17-Dec-18  0.0132820513
# 10  14-Dec-18 -0.0177375914
# 11  13-Dec-18  0.0102379154
# 12  12-Dec-18 -0.0014458058
# 13  11-Dec-18 -0.0015116279
# 14  10-Dec-18 -0.0003760849
# 15  7-Dec-18   0.0040483559
# 16  6-Dec-18  -0.0021947102
# 17  4-Dec-18   0.0068956306
# 18  3-Dec-18  -0.0014132995
# 19  30-Nov-18 -0.0107382304
# 20  29-Nov-18  0.0097420781
# 21  28-Nov-18 -0.0050147656
# 22  27-Nov-18  0.0005240929
# 23  26-Nov-18  0.0069426386
# 24  23-Nov-18 -0.0084021931
# 25  21-Nov-18 -0.0014821256
# 26  20-Nov-18  0.0092885066
# 27  19-Nov-18 -0.0051415094
# 28  16-Nov-18  0.0004174537
# 29  15-Nov-18  0.0074298625
# 30  14-Nov-18 -0.0008759124
# ⋮   ⋮         ⋮
# 221 13-Feb-18 -1.002287e-02
# ...

# %%
#Code to calculate IBM close ratio, adjusted close ratio, difference, and dividend

# %%
ibm_df2 <- ibm_df %>%
  mutate(
    Close_Ratio = lead(Close, n = 1) / Close,
    Adjusted_Close_Ratio = lead(Adj.Close, n = 1) / Adj.Close,
    Difference = Adjusted_Close_Ratio - Close_Ratio,
    Dividend = Difference * Close
    )
ibm_df2
# Out:
#     Date      Open   High   Low    Close  Adj.Close Volume     Close_Ratio
# 1   28-Dec-18 109.20 109.75 107.55 108.06 82.36     5,352,905  1.0066630
# 2   27-Dec-18 105.15 108.78 104.66 108.78 82.91     6,323,698  0.9789483
# 3   26-Dec-18 103.25 106.49 101.28 106.49 81.16     6,951,507  0.9657245
# 4   24-Dec-18 105.07 106.12 102.77 102.84 78.38     3,997,184  1.0313108
# 5   21-Dec-18 107.55 110.21 105.58 106.06 80.84     10,864,279 1.0187630
# 6   20-Dec-18 110.61 111.33 106.79 108.05 82.35     8,843,302  1.0301712
# 7   19-Dec-18 112.00 114.98 110.87 111.31 84.84     7,300,871  1.0018866
# 8   18-Dec-18 111.76 113.03 110.92 111.52 85.00     6,579,549  0.9952475
# 9   17-Dec-18 113.83 114.51 110.01 110.99 84.60     7,713,727  1.0327957
# 10  14-Dec-18 114.24 115.78 114.19 114.63 87.37     4,763,693  1.0068917
# 11  13-Dec-18 115.93 116.43 114.89 115.42 87.97     4,177,306  1.0035522
# 12  12-Dec-18 117.12 117.48 115.68 115.83 88.28     3,724,283  0.9977553
# ...

# %%
#Code for IBM table of date and dividend only.

# %%
select(ibm_df2, Date, Dividend)
# Out:
#     Date      Dividend
# 1   28-Dec-18  1.624575e-03
# 2   27-Dec-18 -6.043903e-03
# 3   26-Dec-18  2.363233e-03
# 4   24-Dec-18  7.690737e-03
# 5   21-Dec-18 -8.918852e-03
# 6   20-Dec-18  7.085610e-03
# 7   19-Dec-18 -8.015087e-05
# 8   18-Dec-18  5.200000e-03
# 9   17-Dec-18 -5.930260e-03
# 10  14-Dec-18 -2.796154e-03
# 11  13-Dec-18 -3.268160e-03
# 12  12-Dec-18  1.070571e-02
# 13  11-Dec-18 -6.967874e-03
# 14  10-Dec-18  4.357580e-03
# 15  7-Dec-18  -1.098206e-03
# 16  6-Dec-18  -7.271016e-03
# 17  4-Dec-18   5.727991e-03
# 18  3-Dec-18   2.869346e-03
# 19  30-Nov-18 -3.324130e-03
# 20  29-Nov-18 -6.778129e-03
# 21  28-Nov-18  5.873689e-03
# 22  27-Nov-18  3.910359e-03
# 23  26-Nov-18 -9.731405e-03
# 24  23-Nov-18  5.218410e-03
# 25  21-Nov-18 -2.037037e-03
# 26  20-Nov-18 -4.742389e-03
# 27  19-Nov-18  7.145791e-03
# 28  16-Nov-18  1.916911e-03
# 29  15-Nov-18 -3.931518e-03
# 30  14-Nov-18 -3.332953e-03
# ⋮   ⋮         ⋮
# 221 13-Feb-18 -0.0089192500
# ...

# %%
#Code to calculate META close ratio, adjusted close ratio, difference, and dividend

# %%
meta_df2 <- meta_df %>%
  mutate(
    Close_Ratio = lead(Close, n = 1) / Close,
    Adjusted_Close_Ratio = lead(Adj.Close, n = 1) / Adj.Close,
    Difference = Adjusted_Close_Ratio - Close_Ratio,
    Dividend = Difference * Close
    )
meta_df2
# Out:
#     Date      Open   High   Low    Close  Adj.Close Volume     Close_Ratio
# 1   28-Dec-18 135.34 135.92 132.20 133.20 132.80    22,627,600 1.0099099
# 2   27-Dec-18 132.44 134.99 129.67 134.52 134.12    31,202,500 0.9974725
# 3   26-Dec-18 126.00 134.24 125.89 134.18 133.78    39,723,400 0.9245789
# 4   24-Dec-18 123.10 129.74 123.02 124.06 123.69    22,066,000 1.0071739
# 5   21-Dec-18 133.39 134.90 123.42 124.95 124.57    56,901,500 1.0676271
# 6   20-Dec-18 130.70 135.57 130.00 133.40 133.00    40,297,900 0.9988006
# 7   19-Dec-18 141.21 144.91 132.50 133.24 132.84    57,404,900 1.0782047
# 8   18-Dec-18 141.08 145.93 139.83 143.66 143.23    24,709,100 0.9758457
# 9   17-Dec-18 143.08 144.92 138.42 140.19 139.77    24,334,000 1.0276054
# 10  14-Dec-18 143.34 146.01 142.51 144.06 143.63    21,785,800 1.0065945
# 11  13-Dec-18 145.57 145.85 143.19 145.01 144.57    18,148,600 0.9964830
# 12  12-Dec-18 143.08 147.19 142.51 144.50 144.07    23,696,900 0.9832526
# ...

# %%
#Code for META table of date and dividend only.

# %%
select(meta_df2, Date, Dividend)
# Out:
#     Date      Dividend
# 1   28-Dec-18  4.140913e-03
# 2   27-Dec-18 -4.698619e-03
# 3   26-Dec-18  2.715594e-03
# 4   24-Dec-18 -2.327334e-03
# 5   21-Dec-18  2.451223e-03
# 6   20-Dec-18  1.189110e-03
# 7   19-Dec-18 -4.707444e-03
# 8   18-Dec-18 -4.277421e-05
# 9   17-Dec-18  4.831738e-03
# 10  14-Dec-18 -1.897344e-05
# 11  13-Dec-18 -5.862436e-04
# 12  12-Dec-18  2.941176e-03
# 13  11-Dec-18 -5.855109e-03
# 14  10-Dec-18  6.395040e-03
# 15  7-Dec-18  -7.793939e-03
# 16  6-Dec-18   2.916020e-03
# 17  4-Dec-18  -1.726022e-03
# 18  3-Dec-18   3.498016e-03
# 19  30-Nov-18  1.180178e-03
# 20  29-Nov-18  1.749784e-03
# 21  28-Nov-18 -1.050024e-03
# 22  27-Nov-18 -7.632177e-03
# 23  26-Nov-18  1.007459e-03
# 24  23-Nov-18  2.354633e-03
# 25  21-Nov-18  2.329020e-03
# 26  20-Nov-18  1.747866e-03
# 27  19-Nov-18 -6.552980e-03
# 28  16-Nov-18  4.079398e-03
# 29  15-Nov-18  1.764706e-03
# 30  14-Nov-18 -4.664959e-01
# ⋮   ⋮         ⋮
# 221 13-Feb-18  1.057441e-02
# ...

# %%
#Code to calculate MICROSOFT close ratio, adjusted close ratio, difference, and dividend

# %%
msft_df2 <- msft_df %>%
  mutate(
    Close_Ratio = lead(Close, n = 1) / Close,
    Adjusted_Close_Ratio = lead(Adj.Close, n = 1) / Adj.Close,
    Difference = Adjusted_Close_Ratio - Close_Ratio,
    Dividend = Difference * Close
    )
msft_df2
# Out:
#     Date      Open   High   Low    Close  Adj.Close Volume      Close_Ratio
# 1   28-Dec-18 102.09 102.41  99.52 100.39  94.81    38,196,300  1.0078693
# 2   27-Dec-18  99.30 101.19  96.40 101.18  95.56    49,498,500  0.9938723
# 3   26-Dec-18  95.14 100.69  93.96 100.56  94.97    51,634,800  0.9360581
# 4   24-Dec-18  97.68  97.97  93.98  94.13  88.90    43,935,200  1.0435568
# 5   21-Dec-18 101.63 103.00  97.46  98.23  92.77    111,242,100 1.0333910
# 6   20-Dec-18 103.05 104.31  98.78 101.51  95.87    70,334,200  1.0214757
# 7   19-Dec-18 103.65 106.88 101.35 103.69  97.93    68,198,200  1.0027004
# 8   18-Dec-18 103.75 104.51 102.52 103.97  98.19    49,319,200  0.9896124
# 9   17-Dec-18 105.41 105.80 101.71 102.89  97.17    56,957,300  1.0305180
# 10  14-Dec-18 108.25 109.26 105.50 106.03 100.14    47,043,100  1.0322550
# 11  13-Dec-18 109.58 110.87 108.63 109.45 103.37    31,333,400  0.9966195
# 12  12-Dec-18 110.89 111.27 109.04 109.08 103.02    36,183,000  0.9955079
# ...

# %%
#Code for MICROSOFT table of date and dividend only.

# %%
select(msft_df2, Date, Dividend)
# Out:
#     Date      Dividend
# 1   28-Dec-18  4.140913e-03
# 2   27-Dec-18 -4.698619e-03
# 3   26-Dec-18  2.715594e-03
# 4   24-Dec-18 -2.327334e-03
# 5   21-Dec-18  2.451223e-03
# 6   20-Dec-18  1.189110e-03
# 7   19-Dec-18 -4.707444e-03
# 8   18-Dec-18 -4.277421e-05
# 9   17-Dec-18  4.831738e-03
# 10  14-Dec-18 -1.897344e-05
# 11  13-Dec-18 -5.862436e-04
# 12  12-Dec-18  2.941176e-03
# 13  11-Dec-18 -5.855109e-03
# 14  10-Dec-18  6.395040e-03
# 15  7-Dec-18  -7.793939e-03
# 16  6-Dec-18   2.916020e-03
# 17  4-Dec-18  -1.726022e-03
# 18  3-Dec-18   3.498016e-03
# 19  30-Nov-18  1.180178e-03
# 20  29-Nov-18  1.749784e-03
# 21  28-Nov-18 -1.050024e-03
# 22  27-Nov-18 -7.632177e-03
# 23  26-Nov-18  1.007459e-03
# 24  23-Nov-18  2.354633e-03
# 25  21-Nov-18  2.329020e-03
# 26  20-Nov-18  1.747866e-03
# 27  19-Nov-18 -6.552980e-03
# 28  16-Nov-18  4.079398e-03
# 29  15-Nov-18  1.764706e-03
# 30  14-Nov-18 -4.664959e-01
# ⋮   ⋮         ⋮
# 221 13-Feb-18  1.057441e-02
# ...
